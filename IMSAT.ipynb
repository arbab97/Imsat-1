# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Setting up the environment

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes

# %%
# !conda env create -f '/content/drive/My Drive/Thesis/imsat_pytorch.yml'

# %% [markdown]
# #importing code

# %%
# %cd '/content'
# Out:
# /content

# %%
# !git clone "https://github.com/arbab97/Imsat-1"
# Out:
# Cloning into 'Imsat-1'...
# remote: Enumerating objects: 70078, done.
# remote: Counting objects: 100% (70078/70078), done.
# remote: Compressing objects: 100% (70064/70064), done.
# remote: Total 70350 (delta 23), reused 70067 (delta 14), pack-reused 272
# Receiving objects: 100% (70350/70350), 57.37 MiB | 28.85 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Checking out files: 100% (70030/70030), done.

# %% [markdown]
# #Getting the Training Data

# %%
## copy zip from colab for speedup
# !cp '/content/drive/My Drive/Thesis/plots_15march_b2.zip' 'plots_15march_b2.zip'
# !unzip 'plots_15march_b2.zip' 
## Now change the working directory

# %% [markdown]
# #Now, Running the code

# %%
# !source activate imsat_pytorch && python 'Imsat-1/Imsat.py'
# Out:
# cuda:0
# ==> Preparing data..
# tcmalloc: large alloc 1866244096 bytes == 0x559cc7d14000 @  0x7f5ee6326b6b 0x7f5ee6346379 0x7f5ea5ff37c5 0x7f5ea5ff578a 0x7f5ea95b3bca 0x7f5ea97fc74b 0x7f5ea9843f77 0x7f5ed74cd442 0x7f5ed74cdb0e 0x7f5ed74d1c2d 0x7f5ed731468a 0x559cc3da3f19 0x559cc3df6a39 0x559cc3d3b66a 0x559cc3d3c4c5 0x559cc3d5ba73 0x559cc3da31ba 0x559cc3da3f78 0x559cc3df6a39 0x559cc3d3b66a 0x559cc3d3c4c5 0x559cc3d5ba73 0x559cc3da31ba 0x559cc3da3f78 0x559cc3df6146 0x559cc3d3b389 0x559cc3d3c2b4 0x559cc3d3c2dc 0x559cc3e52664 0x559cc3e5ca91 0x559cc3e5cc83
# ==> Start training..
# epoch:  1 	 total lost = -0.4694
# epoch:  2 	 total lost = -0.6101
# epoch:  3 	 total lost = -0.6016
# epoch:  4 	 total lost = -0.5889
# epoch:  5 	 total lost = -0.5744
# epoch:  6 	 total lost = -0.5901
# epoch:  7 	 total lost = -0.6094
# epoch:  8 	 total lost = -0.6005
# epoch:  9 	 total lost = -0.6102
# epoch:  10 	 total lost = -0.6316
# epoch:  11 	 total lost = -0.5956
# ...
